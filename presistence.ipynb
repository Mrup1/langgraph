# %%
from langgraph.graph import StateGraph, START, END
from typing import TypedDict
from langchain_ollama import ChatOllama
from dotenv import load_dotenv
from langgraph.checkpoint.memory import InMemorySaver

# %%
load_dotenv()
# Out:
# True

# %%
llm = ChatOllama(
    model="llama3.2", 
    temperature=0.7
)

# %%
class JokeState(TypedDict):
    
    topic: str
    joke: str
    explanation: str

# %%
def generate_joke(state: JokeState):
    
    prompt = f'generate a joke on the topic {state["topic"]}'
    response = llm.invoke(prompt).content

    return {'joke': response}

# %%
def generate_explanation(state: JokeState):
    
    prompt = f'write an explanation for the joke - {state["joke"]}'
    response = llm.invoke(prompt).content

    return {'explanation': response}

# %%
graph = StateGraph(JokeState)

graph.add_node('generate_joke', generate_joke)
graph.add_node('generate_explanation', generate_explanation)

graph.add_edge(START, 'generate_joke')
graph.add_edge('generate_joke', 'generate_explanation')
graph.add_edge('generate_explanation', END)

checkpointer = InMemorySaver()

workflow = graph.compile(checkpointer=checkpointer)

# %%
config1 = {"configurable": {"thread_id": "1"}}
workflow.invoke({'topic':'mango'}, config=config1)
# Out:
# {'topic': 'mango',
#  'joke': "Why did the mango go to therapy?\n\nBecause it wasn't peeling well under the pressure.",
#  'explanation': 'This joke is a play on words, combining the literal and figurative meanings of "peeling" in two ways.\n\nFirstly, a mango has a thick skin that covers its flesh, known as the peel. So, when we say "peeling", it refers to removing this outer layer.\n\nSecondly, "peeling under pressure" is an idiomatic expression that means feeling overwhelmed or stressed by difficult situations.\n\nIn the joke, the punchline "it wasn\'t peeling well under the pressure" is a pun, where the literal meaning of "peeling" as a physical action is replaced with the figurative meaning of emotional stress. It\'s a clever play on words that creates a humorous connection between the mango\'s physical characteristics and its psychological state.\n\nThe joke relies on this wordplay to create a lighthearted and amusing connection between an everyday object (mango) and a relatable human experience (feeling stressed), making it a clever and entertaining pun.'}

# %%
workflow.get_state(config1)
# Out:
# StateSnapshot(values={'topic': 'mango', 'joke': "Why did the mango go to therapy?\n\nBecause it wasn't peeling well under the pressure.", 'explanation': 'This joke is a play on words, combining the literal and figurative meanings of "peeling" in two ways.\n\nFirstly, a mango has a thick skin that covers its flesh, known as the peel. So, when we say "peeling", it refers to removing this outer layer.\n\nSecondly, "peeling under pressure" is an idiomatic expression that means feeling overwhelmed or stressed by difficult situations.\n\nIn the joke, the punchline "it wasn\'t peeling well under the pressure" is a pun, where the literal meaning of "peeling" as a physical action is replaced with the figurative meaning of emotional stress. It\'s a clever play on words that creates a humorous connection between the mango\'s physical characteristics and its psychological state.\n\nThe joke relies on this wordplay to create a lighthearted and amusing connection between an everyday object (mango) and a relatable human experience (feeling stressed), making it a clever and entertaining pun.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1647b6-f721-6842-8006-6e9a165dde6a'}}, metadata={'source': 'loop', 'step': 6, 'parents': {}}, created_at='2026-06-10T03:21:13.869819+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1647b6-bba3-6f86-8005-e32111cc0fbf'}}, tasks=(), interrupts=())

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'mango', 'joke': "Why did the mango go to therapy?\n\nBecause it wasn't peeling well under the pressure.", 'explanation': 'This joke is a play on words, combining the literal and figurative meanings of "peeling" in two ways.\n\nFirstly, a mango has a thick skin that covers its flesh, known as the peel. So, when we say "peeling", it refers to removing this outer layer.\n\nSecondly, "peeling under pressure" is an idiomatic expression that means feeling overwhelmed or stressed by difficult situations.\n\nIn the joke, the punchline "it wasn\'t peeling well under the pressure" is a pun, where the literal meaning of "peeling" as a physical action is replaced with the figurative meaning of emotional stress. It\'s a clever play on words that creates a humorous connection between the mango\'s physical characteristics and its psychological state.\n\nThe joke relies on this wordplay to create a lighthearted and amusing connection between an everyday object (mango) and a relatable human experience (feeling stressed), making it a clever and entertaining pun.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1647b6-f721-6842-8006-6e9a165dde6a'}}, metadata={'source': 'loop', 'step': 6, 'parents': {}}, created_at='2026-06-10T03:21:13.869819+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1647b6-bba3-6f86-8005-e32111cc0fbf'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'mango', 'joke': "Why did the mango go to therapy?\n\nBecause it wasn't peeling well under the pressure.", 'explanation': 'A classic play on words! The joke is a clever pun that relies on the multiple meanings of the word "crusty".\n\nIn this case, "crusty" has two different interpretations:\n\n1. A crusty person might be someone who is grumpy or irritable, which is an emotional state.\n2. Crust is also a characteristic of bread, such as pizza dough, that forms the outer layer when it\'s baked.\n\nThe joke plays on this dual meaning by using "crusty" to describe both the pizza\'s emotional state and its physical texture. The punchline "feeling crusty about its emotions" is a clever connection between the two meanings, implying that the pizza is feeling grumpy or upset because of something related to its emotional state.\n\nThe humor comes from the unexpected twist on the word\'s meaning and the clever way it connects the pizza\'s physical properties with its emotional state. It\'s a lighthearted and silly joke that pokes fun at the idea of emotions being as complicated as a slice of pizza crust!'}, next=('generate_explanation',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1647b6-bba3-6f86-8005-e32111cc0fbf'}}, metadata={'source': 'loop', 'step': 5, 'parents': {}}, created_at='2026-06-10T03:21:07.631847+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1647b6-b23b-6d22-8004-e378de4ddb4e'}}, tasks=(PregelTask(id='c038aafb-363c-5b27-e468-f4c801e5cf51', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': 'This joke is a play on words, combining the literal and figurative meanings of "peeling" in two ways.\n\nFirstly, a mango has a thick skin that covers its flesh, known as the peel. So, when we say "peeling", it refers to removing this outer layer.\n\nSecondly, "peeling under pressure" is an idiomatic expression that means feeling overwhelmed or stressed by difficult situations.\n\nIn the joke, the punchline "it wasn\'t peeling well under the pressure" is a pun, where the literal meaning of "peeling" as a physical action is replaced with the figurative meaning of emotional stress. It\'s a clever play on words that creates a humorous connection between the mango\'s physical characteristics and its psychological state.\n\nThe joke relies on this wordplay to create a lighthearted and amusing connection between an everyday object (mango) and a relatable human experience (feeling stressed), making it a clever and entertaining pun.'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'mango', 'joke': 'Why did the pizza go to therapy?\n\nBecause it was feeling crusty about its emotions.', 'explanation': 'A classic play on words! The joke is a clever pun that relies on the multiple meanings of the word "crusty".\n\nIn this case, "crusty" has two different interpretations:\n\n1. A crusty person might be someone who is grumpy or irritable, which is an emotional state.\n2. Crust is also a characteristic of bread, such as pizza dough, that forms the outer layer when it\'s baked.\n\nThe joke plays on this dual meaning by using "crusty" to describe both the pizza\'s emotional state and its physical texture. The punchline "feeling crusty about its emotions" is a clever connection between the two meanings, implying that the pizza is feeling grumpy or upset because of something related to its emotional state.\n\nThe humor comes from the unexpected twist on the word\'s meaning and the clever way it connects the pizza\'s physical properties with its emotional state. It\'s a lighthearted and silly joke that pokes fun at the idea of emotions being as complicated as a slice of pizza crust!'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1647b6-b23b-6d22-8004-e378de4ddb4e'}}, metadata={'source': 'loop', 'step': 4, 'parents': {}}, created_at='2026-06-10T03:21:06.645524+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1647b6-b237-6a2e-8003-04f5564afc5a'}}, tasks=(PregelTask(id='3f979371-86ca-2c37-6a6d-acfdaa1deade', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': "Why did the mango go to therapy?\n\nBecause it wasn't peeling well under the pressure."}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza go to therapy?\n\nBecause it was feeling crusty about its emotions.', 'explanation': 'A classic play on words! The joke is a clever pun that relies on the multiple meanings of the word "crusty".\n\nIn this case, "crusty" has two different interpretations:\n\n1. A crusty person might be someone who is grumpy or irritable, which is an emotional state.\n2. Crust is also a characteristic of bread, such as pizza dough, that forms the outer layer when it\'s baked.\n\nThe joke plays on this dual meaning by using "crusty" to describe both the pizza\'s emotional state and its physical texture. The punchline "feeling crusty about its emotions" is a clever connection between the two meanings, implying that the pizza is feeling grumpy or upset because of something related to its emotional state.\n\nThe humor comes from the unexpected twist on the word\'s meaning and the clever way it connects the pizza\'s physical properties with its emotional state. It\'s a lighthearted and silly joke that pokes fun at the idea of emotions being as complicated as a slice of pizza crust!'}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1647b6-b237-6a2e-8003-04f5564afc5a'}}, metadata={'source': 'input', 'step': 3, 'parents': {}}, created_at='2026-06-10T03:21:06.643792+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1647b4-abd5-6840-8002-9b7bb5720e36'}}, tasks=(PregelTask(id='84a7f14d-20b5-b96a-5206-6623af54261a', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'mango'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza go to therapy?\n\nBecause it was feeling crusty about its emotions.', 'explanation': 'A classic play on words! The joke is a clever pun that relies on the multiple meanings of the word "crusty".\n\nIn this case, "crusty" has two different interpretations:\n\n1. A crusty person might be someone who is grumpy or irritable, which is an emotional state.\n2. Crust is also a characteristic of bread, such as pizza dough, that forms the outer layer when it\'s baked.\n\nThe joke plays on this dual meaning by using "crusty" to describe both the pizza\'s emotional state and its physical texture. The punchline "feeling crusty about its emotions" is a clever connection between the two meanings, implying that the pizza is feeling grumpy or upset because of something related to its emotional state.\n\nThe humor comes from the unexpected twist on the word\'s meaning and the clever way it connects the pizza\'s physical properties with its emotional state. It\'s a lighthearted and silly joke that pokes fun at the idea of emotions being as complicated as a slice of pizza crust!'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1647b4-abd5-6840-8002-9b7bb5720e36'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-06-10T03:20:12.287311+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1647b4-5fbf-6410-8001-64e1049dfd9a'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza go to therapy?\n\nBecause it was feeling crusty about its emotions.'}, next=('generate_explanation',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1647b4-5fbf-6410-8001-64e1049dfd9a'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-06-10T03:20:04.308769+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1647b3-fce8-672e-8000-4ed8596649df'}}, tasks=(PregelTask(id='035dac79-779b-a80b-e180-6ea04eda44eb', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': 'A classic play on words! The joke is a clever pun that relies on the multiple meanings of the word "crusty".\n\nIn this case, "crusty" has two different interpretations:\n\n1. A crusty person might be someone who is grumpy or irritable, which is an emotional state.\n2. Crust is also a characteristic of bread, such as pizza dough, that forms the outer layer when it\'s baked.\n\nThe joke plays on this dual meaning by using "crusty" to describe both the pizza\'s emotional state and its physical texture. The punchline "feeling crusty about its emotions" is a clever connection between the two meanings, implying that the pizza is feeling grumpy or upset because of something related to its emotional state.\n\nThe humor comes from the unexpected twist on the word\'s meaning and the clever way it connects the pizza\'s physical properties with its emotional state. It\'s a lighthearted and silly joke that pokes fun at the idea of emotions being as complicated as a slice of pizza crust!'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1647b3-fce8-672e-8000-4ed8596649df'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2026-06-10T03:19:53.945057+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1647b3-fce2-6860-bfff-82fd005a5061'}}, tasks=(PregelTask(id='6ebc0b85-157f-6ed8-9b96-7058a17d6f1f', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'Why did the pizza go to therapy?\n\nBecause it was feeling crusty about its emotions.'}),), interrupts=()),
#  StateSnapshot(values={}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1647b3-fce2-6860-bfff-82fd005a5061'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2026-06-10T03:19:53.942629+00:00', parent_config=None, tasks=(PregelTask(id='71882515-7c81-bc77-d65a-d0d48e10ba8b', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'pizza'}),), interrupts=())]

# %%
config2 = {"configurable": {"thread_id": "2"}}
workflow.invoke({'topic':'remote'}, config=config2)
# Out:
# {'topic': 'remote',
#  'joke': 'Why did the remote control go to therapy?\n\nBecause it was feeling a little "disconnected" and had trouble "channeling" its emotions.',
#  'explanation': 'The joke is a play on words, utilizing puns related to both technology and emotional connection.\n\nFirstly, the phrase "feeling a little disconnected" is a common idiom used in therapy settings to describe someone who feels isolated or detached from their feelings, thoughts, or relationships. In this context, it\'s applied to an inanimate object, the remote control, which is often used to disconnect from live television and access pre-recorded content.\n\nSecondly, "channeling" has a double meaning here. In emotional contexts, it refers to expressing or managing one\'s emotions. However, in the context of a TV remote control, "channeling" means selecting a specific channel on the television using the device.\n\nBy using these wordplay techniques, the joke creates a humorous connection between the remote control\'s literal and figurative capabilities, poking fun at its inability to manage its emotions while referencing common human experiences.'}

# %%
list(workflow.get_state_history(config2))
# Out:
# [StateSnapshot(values={'topic': 'remote', 'joke': 'Why did the remote control go to therapy?\n\nBecause it was feeling a little "disconnected" and had trouble "channeling" its emotions.', 'explanation': 'The joke is a play on words, utilizing puns related to both technology and emotional connection.\n\nFirstly, the phrase "feeling a little disconnected" is a common idiom used in therapy settings to describe someone who feels isolated or detached from their feelings, thoughts, or relationships. In this context, it\'s applied to an inanimate object, the remote control, which is often used to disconnect from live television and access pre-recorded content.\n\nSecondly, "channeling" has a double meaning here. In emotional contexts, it refers to expressing or managing one\'s emotions. However, in the context of a TV remote control, "channeling" means selecting a specific channel on the television using the device.\n\nBy using these wordplay techniques, the joke creates a humorous connection between the remote control\'s literal and figurative capabilities, poking fun at its inability to manage its emotions while referencing common human experiences.'}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f1647bd-3c68-6d1e-8002-cef5eb42c040'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-06-10T03:24:02.195501+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f1647bd-0b96-63bc-8001-86e42a753251'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'remote', 'joke': 'Why did the remote control go to therapy?\n\nBecause it was feeling a little "disconnected" and had trouble "channeling" its emotions.'}, next=('generate_explanation',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f1647bd-0b96-63bc-8001-86e42a753251'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-06-10T03:23:57.076154+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f1647bd-0158-66d4-8000-e5a26c6315a6'}}, tasks=(PregelTask(id='dcc6018e-3c41-0e26-e3d7-67a4f38d6a0e', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': 'The joke is a play on words, utilizing puns related to both technology and emotional connection.\n\nFirstly, the phrase "feeling a little disconnected" is a common idiom used in therapy settings to describe someone who feels isolated or detached from their feelings, thoughts, or relationships. In this context, it\'s applied to an inanimate object, the remote control, which is often used to disconnect from live television and access pre-recorded content.\n\nSecondly, "channeling" has a double meaning here. In emotional contexts, it refers to expressing or managing one\'s emotions. However, in the context of a TV remote control, "channeling" means selecting a specific channel on the television using the device.\n\nBy using these wordplay techniques, the joke creates a humorous connection between the remote control\'s literal and figurative capabilities, poking fun at its inability to manage its emotions while referencing common human experiences.'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'remote'}, next=('generate_joke',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f1647bd-0158-66d4-8000-e5a26c6315a6'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2026-06-10T03:23:56.002265+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f1647bd-0150-68a8-bfff-47b4a3cd8398'}}, tasks=(PregelTask(id='776952be-7637-0d3a-32f5-203e3be6cf12', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'Why did the remote control go to therapy?\n\nBecause it was feeling a little "disconnected" and had trouble "channeling" its emotions.'}),), interrupts=()),
#  StateSnapshot(values={}, next=('__start__',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f1647bd-0150-68a8-bfff-47b4a3cd8398'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2026-06-10T03:23:55.999033+00:00', parent_config=None, tasks=(PregelTask(id='25c24ef9-c532-4eb8-d8bc-6bea9c8cd91b', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'remote'}),), interrupts=())]

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'mango', 'joke': "Why did the mango go to therapy?\n\nBecause it wasn't peeling well under the pressure.", 'explanation': 'This joke is a play on words, combining the literal and figurative meanings of "peeling" in two ways.\n\nFirstly, a mango has a thick skin that covers its flesh, known as the peel. So, when we say "peeling", it refers to removing this outer layer.\n\nSecondly, "peeling under pressure" is an idiomatic expression that means feeling overwhelmed or stressed by difficult situations.\n\nIn the joke, the punchline "it wasn\'t peeling well under the pressure" is a pun, where the literal meaning of "peeling" as a physical action is replaced with the figurative meaning of emotional stress. It\'s a clever play on words that creates a humorous connection between the mango\'s physical characteristics and its psychological state.\n\nThe joke relies on this wordplay to create a lighthearted and amusing connection between an everyday object (mango) and a relatable human experience (feeling stressed), making it a clever and entertaining pun.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1647b6-f721-6842-8006-6e9a165dde6a'}}, metadata={'source': 'loop', 'step': 6, 'parents': {}}, created_at='2026-06-10T03:21:13.869819+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1647b6-bba3-6f86-8005-e32111cc0fbf'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'mango', 'joke': "Why did the mango go to therapy?\n\nBecause it wasn't peeling well under the pressure.", 'explanation': 'A classic play on words! The joke is a clever pun that relies on the multiple meanings of the word "crusty".\n\nIn this case, "crusty" has two different interpretations:\n\n1. A crusty person might be someone who is grumpy or irritable, which is an emotional state.\n2. Crust is also a characteristic of bread, such as pizza dough, that forms the outer layer when it\'s baked.\n\nThe joke plays on this dual meaning by using "crusty" to describe both the pizza\'s emotional state and its physical texture. The punchline "feeling crusty about its emotions" is a clever connection between the two meanings, implying that the pizza is feeling grumpy or upset because of something related to its emotional state.\n\nThe humor comes from the unexpected twist on the word\'s meaning and the clever way it connects the pizza\'s physical properties with its emotional state. It\'s a lighthearted and silly joke that pokes fun at the idea of emotions being as complicated as a slice of pizza crust!'}, next=('generate_explanation',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1647b6-bba3-6f86-8005-e32111cc0fbf'}}, metadata={'source': 'loop', 'step': 5, 'parents': {}}, created_at='2026-06-10T03:21:07.631847+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1647b6-b23b-6d22-8004-e378de4ddb4e'}}, tasks=(PregelTask(id='c038aafb-363c-5b27-e468-f4c801e5cf51', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': 'This joke is a play on words, combining the literal and figurative meanings of "peeling" in two ways.\n\nFirstly, a mango has a thick skin that covers its flesh, known as the peel. So, when we say "peeling", it refers to removing this outer layer.\n\nSecondly, "peeling under pressure" is an idiomatic expression that means feeling overwhelmed or stressed by difficult situations.\n\nIn the joke, the punchline "it wasn\'t peeling well under the pressure" is a pun, where the literal meaning of "peeling" as a physical action is replaced with the figurative meaning of emotional stress. It\'s a clever play on words that creates a humorous connection between the mango\'s physical characteristics and its psychological state.\n\nThe joke relies on this wordplay to create a lighthearted and amusing connection between an everyday object (mango) and a relatable human experience (feeling stressed), making it a clever and entertaining pun.'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'mango', 'joke': 'Why did the pizza go to therapy?\n\nBecause it was feeling crusty about its emotions.', 'explanation': 'A classic play on words! The joke is a clever pun that relies on the multiple meanings of the word "crusty".\n\nIn this case, "crusty" has two different interpretations:\n\n1. A crusty person might be someone who is grumpy or irritable, which is an emotional state.\n2. Crust is also a characteristic of bread, such as pizza dough, that forms the outer layer when it\'s baked.\n\nThe joke plays on this dual meaning by using "crusty" to describe both the pizza\'s emotional state and its physical texture. The punchline "feeling crusty about its emotions" is a clever connection between the two meanings, implying that the pizza is feeling grumpy or upset because of something related to its emotional state.\n\nThe humor comes from the unexpected twist on the word\'s meaning and the clever way it connects the pizza\'s physical properties with its emotional state. It\'s a lighthearted and silly joke that pokes fun at the idea of emotions being as complicated as a slice of pizza crust!'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1647b6-b23b-6d22-8004-e378de4ddb4e'}}, metadata={'source': 'loop', 'step': 4, 'parents': {}}, created_at='2026-06-10T03:21:06.645524+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1647b6-b237-6a2e-8003-04f5564afc5a'}}, tasks=(PregelTask(id='3f979371-86ca-2c37-6a6d-acfdaa1deade', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': "Why did the mango go to therapy?\n\nBecause it wasn't peeling well under the pressure."}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza go to therapy?\n\nBecause it was feeling crusty about its emotions.', 'explanation': 'A classic play on words! The joke is a clever pun that relies on the multiple meanings of the word "crusty".\n\nIn this case, "crusty" has two different interpretations:\n\n1. A crusty person might be someone who is grumpy or irritable, which is an emotional state.\n2. Crust is also a characteristic of bread, such as pizza dough, that forms the outer layer when it\'s baked.\n\nThe joke plays on this dual meaning by using "crusty" to describe both the pizza\'s emotional state and its physical texture. The punchline "feeling crusty about its emotions" is a clever connection between the two meanings, implying that the pizza is feeling grumpy or upset because of something related to its emotional state.\n\nThe humor comes from the unexpected twist on the word\'s meaning and the clever way it connects the pizza\'s physical properties with its emotional state. It\'s a lighthearted and silly joke that pokes fun at the idea of emotions being as complicated as a slice of pizza crust!'}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1647b6-b237-6a2e-8003-04f5564afc5a'}}, metadata={'source': 'input', 'step': 3, 'parents': {}}, created_at='2026-06-10T03:21:06.643792+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1647b4-abd5-6840-8002-9b7bb5720e36'}}, tasks=(PregelTask(id='84a7f14d-20b5-b96a-5206-6623af54261a', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'mango'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza go to therapy?\n\nBecause it was feeling crusty about its emotions.', 'explanation': 'A classic play on words! The joke is a clever pun that relies on the multiple meanings of the word "crusty".\n\nIn this case, "crusty" has two different interpretations:\n\n1. A crusty person might be someone who is grumpy or irritable, which is an emotional state.\n2. Crust is also a characteristic of bread, such as pizza dough, that forms the outer layer when it\'s baked.\n\nThe joke plays on this dual meaning by using "crusty" to describe both the pizza\'s emotional state and its physical texture. The punchline "feeling crusty about its emotions" is a clever connection between the two meanings, implying that the pizza is feeling grumpy or upset because of something related to its emotional state.\n\nThe humor comes from the unexpected twist on the word\'s meaning and the clever way it connects the pizza\'s physical properties with its emotional state. It\'s a lighthearted and silly joke that pokes fun at the idea of emotions being as complicated as a slice of pizza crust!'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1647b4-abd5-6840-8002-9b7bb5720e36'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-06-10T03:20:12.287311+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1647b4-5fbf-6410-8001-64e1049dfd9a'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza go to therapy?\n\nBecause it was feeling crusty about its emotions.'}, next=('generate_explanation',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1647b4-5fbf-6410-8001-64e1049dfd9a'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-06-10T03:20:04.308769+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1647b3-fce8-672e-8000-4ed8596649df'}}, tasks=(PregelTask(id='035dac79-779b-a80b-e180-6ea04eda44eb', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': 'A classic play on words! The joke is a clever pun that relies on the multiple meanings of the word "crusty".\n\nIn this case, "crusty" has two different interpretations:\n\n1. A crusty person might be someone who is grumpy or irritable, which is an emotional state.\n2. Crust is also a characteristic of bread, such as pizza dough, that forms the outer layer when it\'s baked.\n\nThe joke plays on this dual meaning by using "crusty" to describe both the pizza\'s emotional state and its physical texture. The punchline "feeling crusty about its emotions" is a clever connection between the two meanings, implying that the pizza is feeling grumpy or upset because of something related to its emotional state.\n\nThe humor comes from the unexpected twist on the word\'s meaning and the clever way it connects the pizza\'s physical properties with its emotional state. It\'s a lighthearted and silly joke that pokes fun at the idea of emotions being as complicated as a slice of pizza crust!'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1647b3-fce8-672e-8000-4ed8596649df'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2026-06-10T03:19:53.945057+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1647b3-fce2-6860-bfff-82fd005a5061'}}, tasks=(PregelTask(id='6ebc0b85-157f-6ed8-9b96-7058a17d6f1f', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'Why did the pizza go to therapy?\n\nBecause it was feeling crusty about its emotions.'}),), interrupts=()),
#  StateSnapshot(values={}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1647b3-fce2-6860-bfff-82fd005a5061'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2026-06-10T03:19:53.942629+00:00', parent_config=None, tasks=(PregelTask(id='71882515-7c81-bc77-d65a-d0d48e10ba8b', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'pizza'}),), interrupts=())]

# %%
workflow.get_state({"configurable": {"thread_id": "1", "checkpoint_id": "1f06cc6e-7232-6cb1-8000-f71609e6cec5"}})
# Out:
# StateSnapshot(values={}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_id': '1f06cc6e-7232-6cb1-8000-f71609e6cec5'}}, metadata=None, created_at=None, parent_config=None, tasks=(), interrupts=())
